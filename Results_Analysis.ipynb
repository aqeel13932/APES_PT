# %% [markdown]
# # Analaysis of Results.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# Settings,
# * WorldSize (11,11)
# * BlockSize (20,20)
# * Max Steps : 1000
# * Food Reward : 10
# * Step Punishment: -1
# * Detials : one agent following food , 1000 Steps ,
# * layers,1
# * tau,0.001
# * optimizer,adam
# * advantage,naive
# * max_timesteps,1000
# * gym_record,None
# * activation,tanh
# * batch_size,100
# * episodes,1200
# * exploration,0.1
# * gamma,0.99
# * hidden_size,100
# * train_repeat,10
# * display,True
# * min_train,10
# * batch_norm,False

# %%
df = pd.read_csv('output/1474081040/exp_details.csv',header=None)#,delimiter=',')
df.columns = ['Episode','Steps','Reward','Time']
df.head(5)
# Out:
#    Episode  Steps  Reward        Time
# 0        1    147    -137   39.922307
# 1        2     73     -63   27.529011
# 2        3   1000   -1000  371.962601
# 3        4    262    -252   97.940555
# 4        5    178    -168   67.124835

# %%
df.plot('Episode','Steps',figsize=(10,10))

# %%
df.plot(figsize=(10,10))

# %%
df.plot('Episode','Steps',figsize=(10,10),kind='kde')

# %%
df.plot('Episode','Steps',figsize=(10,10),kind='hist')

# %%
df['Steps_norm'] = (df.Steps - df.Steps.mean()) / (df.Steps.max() - df.Steps.min())

# %%
df.plot('Episode','Steps_norm',figsize=(10,10))
